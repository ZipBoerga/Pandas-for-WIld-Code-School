# %% [markdown]
# # Imports

# %%
from datetime import datetime
from datetime import timedelta
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Your mission: convert each string variable into datetime objects

# %%
var1 = '2018-01-04'
print(type(var1))
print(var1)
# Out:
# <class 'str'>
# 2018-01-04

# %%
datetime_obj1 = datetime.strptime(var1, '%Y-%m-%d')
print(type(datetime_obj1))
print(datetime_obj1)
# Out:
# <class 'datetime.datetime'>
# 2018-01-04 00:00:00

# %%
var2 = '14/02/2019'
datetime_obj2 = datetime.strptime(var2, '%d/%m/%Y')
print(datetime_obj2)
# Out:
# 2019-02-14 00:00:00

# %%
var3 = '14 03 20'
datetime_obj3 = datetime.strptime(var3, '%d %m %y')
print(datetime_obj3)
# Out:
# 2020-03-14 00:00:00

# %%
var4 = '14/02/2019 21:30'
datetime_obj4 = datetime.strptime(var4, '%d/%m/%Y %H:%M')
print(datetime_obj4)
# Out:
# 2019-02-14 21:30:00

# %%
var5 = '2018-01-04 at 18 hours and 48 min'
datetime_obj5 = datetime.strptime(var5, '%Y-%m-%d at %H hours and %M min')
print(datetime_obj5)
# Out:
# 2018-01-04 18:48:00

# %% [markdown]
# # Your mission: convert the datetime object into string with precise format

# %%
var_date = datetime.strptime('2020-02-15 20:05', '%Y-%m-%d %H:%M')
print(var_date)
# Out:
# 2020-02-15 20:05:00

# %%
# We would like to print this format : 15/02/2020
var_date.strftime('%d/%m/%Y')
# Out:
# '15/02/2020'

# %%
# We would like to print this format : 15-02-2020
var_date.strftime('%d-%m-%Y')
# Out:
# '15-02-2020'

# %%
# We would like to print this format : 15/02
var_date.strftime('%d/%m')
# Out:
# '15/02'

# %%
# We would like to print this format : 2020-02
var_date.strftime('%Y-%m')
# Out:
# '2020-02'

# %%
# We would like to print this format : 2020-02-15 at 20:05
var_date.strftime('%Y-%m-%d at %H:%M')
# Out:
# '2020-02-15 at 20:05'

# %% [markdown]
# # Your mission is to determine which date it was / it will be

# %%
# what month will it be in 7 weeks ?
then_date = datetime.now() + timedelta(weeks=7)
print(then_date.strftime("%B"))
# Out:
# October

# %%
# what day of the week will it be in 3 days ?
then_date = datetime.now() + timedelta(days=3)
print(then_date.strftime("%A"))
# Out:
# Friday

# %%
# what hour will it be in 100 hours ?
then_date = datetime.now() + timedelta(hours=100)
print(then_date.strftime("%H"))
# Out:
# 15

# %%
# what date was 30 days ago ?
then_date = datetime.now() - timedelta(days=30)
print(then_date.strftime("%d/%m"))
# Out:
# 30/07

# %%
# what date was 30 weeks ago ?
then_date = datetime.now() - timedelta(weeks=30)
print(then_date.strftime("%d/%m"))
# Out:
# 31/01

# %% [markdown]
# # With Pandas
# "DATE" column has only string values. On a chart, the X-axis is not well displayed.

# %%
# Please run this cell without modification:
df = pd.read_csv("https://raw.githubusercontent.com/murpi/wilddata/master/quests/weather2019.csv")
fig, ax = plt.subplots(figsize=(20, 10))
ax.scatter(x=df['DATE'],
           y=df['MAX_TEMPERATURE_C'])
fig.show()

# %%
# Convert the "DATE" column into a datetime format, then display the same chart. Are ticks on X-axis better printed ?
# df.DATE = df.DATE.apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
df.DATE = pd.to_datetime(df.DATE, format='%Y-%m-%d')
df
# Out:
#           DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0   2019-01-01                  9                  4                 10
# 1   2019-01-02                  8                  5                 18
# 2   2019-01-03                  6                  0                 18
# 3   2019-01-04                  5                 -1                 15
# 4   2019-01-05                  6                 -1                  8
# ..         ...                ...                ...                ...
# 360 2019-12-27                 13                 10                 13
# 361 2019-12-28                 11                  5                 12
# 362 2019-12-29                  9                  2                 11
# 363 2019-12-30                 12                  4                  7
# 364 2019-12-31                 10                  4                 13
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                        4                   7                      8
# 1                        7                   7                      5
# 2                        0                   4                      3
# 3                       -1                   4                      3
# 4                       -1                   4                      3
# ..                     ...                 ...                    ...
# 360                     10                  12                     11
# 361                      7                   8                      8
# 362                      3                   6                      7
# 363                      5                   9                      9
# 364                      4                   7                      9
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0                    0.2                    94              9.000  ...
# 1                    0.0                    90              9.000  ...
# 2                    0.0                    88             10.000  ...
# 3                    0.0                    91             10.000  ...
# 4                    0.0                    91              8.000  ...
# ..                   ...                   ...                ...  ...
# 360                  0.0                    96              7.375  ...
# 361                  0.0                    93              7.625  ...
# 362                  0.0                    86             10.000  ...
# 363                  0.0                    61             10.000  ...
# 364                  0.1                    94              9.000  ...
#
#      WINDTEMP_MAX_C  WEATHER_CODE_MORNING  WEATHER_CODE_NOON  \
# 0                 3                   116                143
# 1                 3                   119                116
# 2                -4                   116                116
# 3                -4                   116                116
# 4                -2                   143                116
# ..              ...                   ...                ...
# 360               8                   119                143
# 361               4                   143                116
# 362               0                   116                116
# 363               4                   113                113
# 364               1                   113                143
#
#      WEATHER_CODE_EVENING  TOTAL_SNOW_MM  UV_INDEX  SUNHOUR           OPINION  \
# 0                     176              0         1      5.1          very bad
# 1                     116              0         1      8.7          very bad
# 2                     116              0         1      8.7          very bad
# 3                     122              0         1      5.1          very bad
# 4                     116              0         1      8.7          very bad
# ..                    ...            ...       ...      ...               ...
# 360                   116              0         1      8.7  not good not bad
# 361                   116              0         1      6.9          very bad
# 362                   116              0         1      8.7          very bad
# 363                   113              0         1      8.7          very bad
# 364                   119              0         1      8.7          very bad
#
#      MONTH  DAY
# 0        1    1
# 1        1    2
# 2        1    3
# 3        1    4
# 4        1    5
# ..     ...  ...
# 360     12   27
# 361     12   28
# 362     12   29
# 363     12   30
# 364     12   31
#
# [365 rows x 24 columns]

# %%
# function for plotting
def display_plot(df):
  fig, ax = plt.subplots(figsize=(20, 10))
  ax.scatter(x=df['DATE'],
             y=df['MAX_TEMPERATURE_C'])
  fig.show()

# %%
display_plot(df)

# %%
# Display only rows for the month of June
df = df[(df.DATE >= "2019-07-01") & (df.DATE <= "2019-07-31")]
display_plot(df)
